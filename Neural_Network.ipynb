# %% [markdown]
# # Perceptron to Neural Network
# * Neural network consists of input layer, output layer and hidden layer(s).
#
# # Activation function
# * activation function determine whther the sum of inputs causes activation or not.
#
# # Step fucntion
# * A step function is a mathematical function that remains constant within certain intervals and changes values
